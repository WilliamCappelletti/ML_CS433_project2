# %%
'''
 script to reproduce the plots from the report
'''

import pandas as pd
import os
import random
import matplotlib.pyplot as plt
from sklearn import datasets
import seaborn as sns


from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, explained_variance_score
import regressions

from matplotlib import rcParams

sns.set()
rcParams['axes.titlepad'] = 20



from numpy import exp,arange
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show
import numpy as np
import xgboost as xgb
import plots




#-------------------------------------------------------------------------------
# Load the data
#-------------------------------------------------------------------------------

y1, y2, y3, y4, X, realization = regressions.data_initialization(realiz=True)
X = X.drop(columns=['sigma_mass_0.0', 'sigma_mass_0.825', 'enzyme_concentration'])
X_panda = X.copy()
X = X.values


#-------------------------------------------------------------------------------
# constants definition
#-------------------------------------------------------------------------------
# heuristic for the xgboost model, taken from the median of the training data

P0 = np.median(X_panda.product_concentration.values)
S0 = np.median(X_panda.substrate_concentration.values)
ES0 = np.median(X_panda.enzyme_complex_concentration.values)
mu0 = np.median(X_panda.mu_mass.values)
v0 = 0.3

#parameters for the model xgboost obtained via cross validation
param = {'max_depth': 10, 'eta': 1, 'silent': 1, 'subsample': 0.8}
# param['nthread'] = 4
param['reg_alpha'] = 0.7
# param['reg_lamda'] = 0.5
param['tree_method'] = 'auto'

#-------------------------------------------------------------------------------
# Train the models and save the plots
#-------------------------------------------------------------------------------

for y,name in  [[y1,'y1'],[y2,'y2'],[y3,'y3'],[y4,'y4']]:
    print("training and plotting for response ",name)
    plots.plot_evolution(model_parameters= param,X = X,y = y,name = name,base = np.array([ES0,mu0,P0,S0,v0]))
# Out:
# training and plotting for response  y1
# volume  0.0
# volume  0.1
# volume  0.2
# volume  0.3
# volume  0.4
# volume  0.5
# training and plotting for response  y2
# volume  0.0
# volume  0.1
# volume  0.2
# volume  0.3
# volume  0.4
# volume  0.5
# training and plotting for response  y3
# volume  0.0
# volume  0.1
# volume  0.2
# volume  0.3
# volume  0.4
# volume  0.5
# training and plotting for response  y4
# volume  0.0
# volume  0.1
# volume  0.2
# volume  0.3
# volume  0.4
# volume  0.5

# %%
import numpy as np
import pandas as pd
import os
import random
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn import svm
import seaborn as sns 

from numpy import arange

import statsmodels.api as sm
sns.set()


from sklearn.linear_model import RidgeCV, LinearRegression
from sklearn.svm import SVR
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, explained_variance_score
import xgboost as xgb


import reproduction
import marie
import regressions
# %load_ext autoreload
# %autoreload 2



from matplotlib import rcParams
rcParams['axes.titlepad'] = 20

# %%
y1, y2, y3, y4, X, realization = regressions.data_initialization(realiz=True)

Y = np.column_stack((y1, y1, y3, y4))

X = X.drop(columns=['sigma_mass_0.0', 'sigma_mass_0.825', 'enzyme_concentration'])
X_panda = X.copy()
X = X.values

# %%
param = {'max_depth': 10, 'eta': 1, 'silent': 1, 'subsample': 0.8}
# param['nthread'] = 4
param['reg_alpha'] = 0.7
# param['reg_lamda'] = 0.5
param['tree_method'] = 'auto'

dtrain1 = xgb.DMatrix(X, label=y1)
xgbReg = xgb.train(params=param, dtrain=dtrain1)

# %%
# heuristic for the xgboost model
P0 = np.median(X_panda.product_concentration.values)
S0 = np.median(X_panda.substrate_concentration.values)
ES0 = np.median(X_panda.enzyme_complex_concentration.values)
mu0 = np.median(X_panda.mu_mass.values)
v0 = 0.3

# %%
for y,name in  [[y1,'y1'],[y2,'y2'],[y3,'y3'],[y4,'y4']]:
    plots.plot_evolution(model_parameters= param,X = X,y = y,name = name,base = np.array([ES0,mu0,P0,S0,v0]))
# Out:
#
# VOLUME  0.0
#
# borne for the plots:  2.27 2.3
# borne for the plots:  2.27 2.3
# combinaison already done:  P   ES
# borne for the plots:  2.27 2.3
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.1
#
# borne for the plots:  1.94 2.21
# borne for the plots:  1.94 2.21
# combinaison already done:  P   ES
# borne for the plots:  1.94 2.21
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.2
#
# borne for the plots:  1.42 2.06
# borne for the plots:  1.42 2.06
# combinaison already done:  P   ES
# borne for the plots:  1.42 2.06
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.3
#
# borne for the plots:  0.6 1.81
# borne for the plots:  0.6 1.81
# combinaison already done:  P   ES
# borne for the plots:  0.6 1.81
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.4
#
# borne for the plots:  -0.57 1.38
# borne for the plots:  -0.57 1.38
# combinaison already done:  P   ES
# borne for the plots:  -0.57 1.38
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.5
#
# borne for the plots:  -1.54 0.15
# borne for the plots:  -1.54 0.15
# combinaison already done:  P   ES
# borne for the plots:  -1.54 0.15
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.0
#
# borne for the plots:  10.55 12.69
# borne for the plots:  10.55 12.69
# combinaison already done:  P   ES
# borne for the plots:  10.55 12.69
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.1
#
# borne for the plots:  10.6 13.13
# borne for the plots:  10.6 13.13
# combinaison already done:  P   ES
# borne for the plots:  10.6 13.13
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.2
#
# borne for the plots:  9.25 13.42
# borne for the plots:  9.25 13.42
# combinaison already done:  P   ES
# borne for the plots:  9.25 13.42
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.3
#
# borne for the plots:  10.98 13.56
# borne for the plots:  10.98 13.56
# combinaison already done:  P   ES
# borne for the plots:  10.98 13.56
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.4
#
# borne for the plots:  11.56 13.75
# borne for the plots:  11.56 13.75
# combinaison already done:  P   ES
# borne for the plots:  11.56 13.75
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.5
#
# borne for the plots:  12.26 13.86
# borne for the plots:  12.26 13.86
# combinaison already done:  P   ES
# borne for the plots:  12.26 13.86
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.0
#
# borne for the plots:  11.46 13.7
# borne for the plots:  11.46 13.7
# combinaison already done:  P   ES
# borne for the plots:  11.46 13.7
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.1
#
# borne for the plots:  11.12 13.79
# borne for the plots:  11.12 13.79
# combinaison already done:  P   ES
# borne for the plots:  11.12 13.79
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.2
#
# borne for the plots:  11.82 14.22
# borne for the plots:  11.82 14.22
# combinaison already done:  P   ES
# borne for the plots:  11.82 14.22
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.3
#
# borne for the plots:  11.8 14.29
# borne for the plots:  11.8 14.29
# combinaison already done:  P   ES
# borne for the plots:  11.8 14.29
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.4
#
# borne for the plots:  11.59 14.53
# borne for the plots:  11.59 14.53
# combinaison already done:  P   ES
# borne for the plots:  11.59 14.53
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.5
#
# borne for the plots:  12.51 14.59
# borne for the plots:  12.51 14.59
# combinaison already done:  P   ES
# borne for the plots:  12.51 14.59
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.0
#
# borne for the plots:  3.06 3.09
# borne for the plots:  3.06 3.09
# combinaison already done:  P   ES
# borne for the plots:  3.06 3.09
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.1
#
# borne for the plots:  2.72 2.99
# borne for the plots:  2.72 2.99
# combinaison already done:  P   ES
# borne for the plots:  2.72 2.99
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.2
#
# borne for the plots:  2.21 2.85
# borne for the plots:  2.21 2.85
# combinaison already done:  P   ES
# borne for the plots:  2.21 2.85
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.3
#
# borne for the plots:  1.39 2.6
# borne for the plots:  1.39 2.6
# combinaison already done:  P   ES
# borne for the plots:  1.39 2.6
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.4
#
# borne for the plots:  0.21 2.16
# borne for the plots:  0.21 2.16
# combinaison already done:  P   ES
# borne for the plots:  0.21 2.16
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.5
#
# borne for the plots:  -0.75 0.94
# borne for the plots:  -0.75 0.94
# combinaison already done:  P   ES
# borne for the plots:  -0.75 0.94
# combinaison already done:  S   ES
# combinaison already done:  S   P

# %%
for y,name in  [[y1,'y1'],[y2,'y2'],[y3,'y3'],[y4,'y4']]:
    plots.plot_evolution(model_parameters= param,X = X,y = y,name = name,base = np.array([ES0,mu0,P0,S0,v0]))
# Out:
#
# VOLUME  0.0
#
# borne for the plots:  2.27 2.3
# borne for the plots:  2.27 2.3
# combinaison already done:  P   ES
# borne for the plots:  2.27 2.3
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.1
#
# borne for the plots:  1.94 2.21
# borne for the plots:  1.94 2.21
# combinaison already done:  P   ES
# borne for the plots:  1.94 2.21
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.2
#
# borne for the plots:  1.42 2.06
# borne for the plots:  1.42 2.06
# combinaison already done:  P   ES
# borne for the plots:  1.42 2.06
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.3
#
# borne for the plots:  0.6 1.81
# borne for the plots:  0.6 1.81
# combinaison already done:  P   ES
# borne for the plots:  0.6 1.81
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.4
#
# borne for the plots:  -0.57 1.38
# borne for the plots:  -0.57 1.38
# combinaison already done:  P   ES
# borne for the plots:  -0.57 1.38
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.5
#
# borne for the plots:  -1.54 0.15
# borne for the plots:  -1.54 0.15
# combinaison already done:  P   ES
# borne for the plots:  -1.54 0.15
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.0
#
# borne for the plots:  10.55 12.69
# borne for the plots:  10.55 12.69
# combinaison already done:  P   ES
# borne for the plots:  10.55 12.69
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.1
#
# borne for the plots:  10.6 13.13
# borne for the plots:  10.6 13.13
# combinaison already done:  P   ES
# borne for the plots:  10.6 13.13
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.2
#
# borne for the plots:  9.25 13.42
# borne for the plots:  9.25 13.42
# combinaison already done:  P   ES
# borne for the plots:  9.25 13.42
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.3
#
# borne for the plots:  10.98 13.56
# borne for the plots:  10.98 13.56
# combinaison already done:  P   ES
# borne for the plots:  10.98 13.56
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.4
#
# borne for the plots:  11.56 13.75
# borne for the plots:  11.56 13.75
# combinaison already done:  P   ES
# borne for the plots:  11.56 13.75
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.5
#
# borne for the plots:  12.26 13.86
# borne for the plots:  12.26 13.86
# combinaison already done:  P   ES
# borne for the plots:  12.26 13.86
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.0
#
# borne for the plots:  11.46 13.7
# borne for the plots:  11.46 13.7
# combinaison already done:  P   ES
# borne for the plots:  11.46 13.7
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.1
#
# borne for the plots:  11.12 13.79
# borne for the plots:  11.12 13.79
# combinaison already done:  P   ES
# borne for the plots:  11.12 13.79
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.2
#
# borne for the plots:  11.82 14.22
# borne for the plots:  11.82 14.22
# combinaison already done:  P   ES
# borne for the plots:  11.82 14.22
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.3
#
# borne for the plots:  11.8 14.29
# borne for the plots:  11.8 14.29
# combinaison already done:  P   ES
# borne for the plots:  11.8 14.29
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.4
#
# borne for the plots:  11.59 14.53
# borne for the plots:  11.59 14.53
# combinaison already done:  P   ES
# borne for the plots:  11.59 14.53
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.5
#
# borne for the plots:  12.51 14.59
# borne for the plots:  12.51 14.59
# combinaison already done:  P   ES
# borne for the plots:  12.51 14.59
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.0
#
# borne for the plots:  3.06 3.09
# borne for the plots:  3.06 3.09
# combinaison already done:  P   ES
# borne for the plots:  3.06 3.09
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.1
#
# borne for the plots:  2.72 2.99
# borne for the plots:  2.72 2.99
# combinaison already done:  P   ES
# borne for the plots:  2.72 2.99
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.2
#
# borne for the plots:  2.21 2.85
# borne for the plots:  2.21 2.85
# combinaison already done:  P   ES
# borne for the plots:  2.21 2.85
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.3
#
# borne for the plots:  1.39 2.6
# borne for the plots:  1.39 2.6
# combinaison already done:  P   ES
# borne for the plots:  1.39 2.6
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.4
#
# borne for the plots:  0.21 2.16
# borne for the plots:  0.21 2.16
# combinaison already done:  P   ES
# borne for the plots:  0.21 2.16
# combinaison already done:  S   ES
# combinaison already done:  S   P
#
# VOLUME  0.5
#
# borne for the plots:  -0.75 0.94
# borne for the plots:  -0.75 0.94
# combinaison already done:  P   ES
# borne for the plots:  -0.75 0.94
# combinaison already done:  S   ES
# combinaison already done:  S   P

# %%
limits_d ={ 0.0: {'y1': 2.27,'y2': 10.55,'y3':11.46,'y4':3.06},
            0.1: {'y1': 1.94,'y2': 10.6, 'y3':11.12,'y4':2.72},
            0.2: {'y1': 1.42,'y2': 9.25, 'y3':11.82,'y4':2.21},
            0.3: {'y1': 0.60,'y2': 10.98,'y3':11.8, 'y4':1.39},
            0.4: {'y1':-0.57,'y2': 11.56,'y3':11.59,'y4':0.21},
            0.5: {'y1':-1.54,'y2': 12.26,'y3':12.51,'y4':-0.75}}

limits_u ={ 0.0: {'y1': 2.3, 'y2': 12.69,'y3':13.7,'y4':3.09},
            0.1: {'y1': 2.21,'y2': 13.13,'y3':13.79,'y4':2.99},
            0.2: {'y1': 2.06,'y2': 13.42,'y3':14.22,'y4':2.85},
            0.3: {'y1': 1.81,'y2': 13.56,'y3':14.29,'y4': 2.6},
            0.4: {'y1': 1.38,'y2': 13.75,'y3':14.53,'y4': 2.16},
            0.5: {'y1': 0.15,'y2': 13.86,'y3':14.59,'y4': 0.94}}

# %%
base = np.array([ES0,mu0,P0,S0,v0])
base[-1]
# Out:
# 0.3
